# %%
import numpy as np
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

data = pd.read_csv('ds2os_coded.csv')

data.iloc[:, 1:13].head()
# Out:
#    sourceID_code  sourceAddress_code  sourceType_code  sourceLocation_code  \
# 0             21                  30                2                    3
# 1             32                  70                2                    4
# 2             15                   1                2                    2
# 3             33                  77                2                    7
# 4             55                  78                3                    7
#
#    destinationServiceAddress_code  destinationServiceType_code  \
# 0                              30                            2
# 1                              68                            2
# 2                               0                            2
# 3                              73                            2
# 4                              74                            3
#
#    destinationLocation_code  accessedNodeAddress_code  accessedNodeType_code  \
# ...

# %%
for i in data.columns[1:13]:
    # create a figure and axis
    fig, ax = plt.subplots()
    # scatter the sourceID against the normality
    ax.scatter(data.loc[:, i], data.iloc[:, 12])
    # set a title and labels
    ax.set_title(i + ' against the normality')
    ax.set_xlabel(i)
    ax.set_ylabel('normality')

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data[1:14], hue='normality_code')
# Out:
# C:\Users\Rhishabh\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Rhishabh\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
# import os
# from os import path 

# if not path.exists('pictures'):
#     os.mkdir('pictures')
# g.savefig(os.path.join('pictures', 'pairplot'))
